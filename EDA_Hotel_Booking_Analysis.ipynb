# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyesh0411/EDA-Hotel-Booking-Analysis-Project/blob/main/EDA_Hotel_Booking_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Hotel Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -**   Priyesh Singh

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# > **Hotel Booking Data Analysis Project consists of two hotels**.
# 1. Resort Hotel
# 2. City Hotel
#
# - **We will do the analysis of these two hotels from year 2015-2017**.
#
# **In this data analysis, it has information such as**
# 01. Type of hotel booked,
# 02. Average daily rate(ADR),
# 03. Booking details,
# 04. Arrival date,
# 05. Length of the stay,
# 06. The number of adults, children, and / or babies booked,
# 07. Customer country,
# 08. Meal preferences,
# 09. Type of the customer,
# 10. Parking space details,
# 11. Reservation status,
# 12. Channels used for booking,
# 13. Booking cancellation details,
# 14. Booking lead time details,
#
#     among other details.
#
# > - **"Pandas" library** will be used for **Data Manipulation & Aggregation**.
# - **"MatPlotLib" & "Seaborn"** Will be used for **Data Visualization**.
# - **"NumPy"** will be used for **Computationally Efficient Operations**.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# In recent years, City hotel & Resort hotel have seen **high cancellation rates**.
#
# Each hotel is now dealing with a number of issues as a result, **including fewer revenues and less than ideal hotel room use**.
#
# Consequently, lowering cancellation rates is both hotels primary goal in order to increase their efficiency in generating revenue.
#
# **For us to offer thorough business advice to address this problem.
# The analysis of hotel booking cancellations as well as other factors that have no bearing on their business and yearly revenue generation are the main topics of this report.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# **The business objective here is to Explore the data and find the solutions of the problems such as:**
#
# **1.** What are the variables that affect hotels reservation cancellations?
#
# **2.** How can we make hotel reservation cancellations better?
#
# **3.** How will hotels be assisted in making pricing and promotional decisions?

# %% [markdown]
# ### **Hypothesis**

# %% [markdown]
# - More cancellations occurs when prices are higher.
# - When there is a longer waiting list, customers tend to cancel more frequently.
# - The majority of customers are coming from offline travel agents to make their reservations.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset
df = pd.read_csv("/content/Hotel Bookings.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
row, column = df.shape
print("Total number of rows in Data: ",row)
print("Total number of column in Data: ",column)
# Out:
# Total number of rows in Data:  119390
# Total number of column in Data:  32

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# Here "reservation status date" is "Object" but it should be in "datetime".
df["reservation_status_date"] = pd.to_datetime(df["reservation_status_date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe(include = "object")
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %%
for col in df.describe(include = "object").columns:
  print("> Col_Name : ",col)
  print("\n> Unique_Values : ","\n",df[col].unique())
  print("\n \n")
# Out:
# > Col_Name :  hotel
#
# > Unique_Values :
#  ['Resort Hotel' 'City Hotel']
#
#
#
# > Col_Name :  arrival_date_month
#
# > Unique_Values :
#  ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
#
#
#
# > Col_Name :  meal
#
# > Unique_Values :
#  ['BB' 'FB' 'HB' 'SC' 'Undefined']
#
#
#
# > Col_Name :  country
#
# > Unique_Values :
#  ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df[df.duplicated()].shape
# Out:
# (31994, 32)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Here agent & company has too much missing values as compared to data we have.
# we have to drop it.
columns_to_drop = ["agent","company"]
df = df.drop(columns=columns_to_drop)

# %%
# we now check if the agent & company has been dropped.
df.isnull().sum()
# Out:
# hotel                               0
# is_canceled                         0
# lead_time                           0
# arrival_date_year                   0
# arrival_date_month                  0
# arrival_date_week_number            0
# arrival_date_day_of_month           0
# stays_in_weekend_nights             0
# stays_in_week_nights                0
# adults                              0
# children                            4
# babies                              0
# meal                                0
# country                           488
# market_segment                      0
# distribution_channel                0
# is_repeated_guest                   0
# previous_cancellations              0
# previous_bookings_not_canceled      0
# reserved_room_type                  0
# assigned_room_type                  0
# booking_changes                     0
# deposit_type                        0
# days_in_waiting_list                0
# customer_type                       0
# ...

# %%
# we can also see that children and country has also missing values.
df.dropna(inplace = True)

# %%
# we again check the children & country values.
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %% [markdown]
# **Now there is no missing/Null values**

# %%
# Visualizing the missing values
df.isnull().sum().sort_values(ascending = False)[:10]
# Out:
# hotel                          0
# is_canceled                    0
# reservation_status             0
# total_of_special_requests      0
# required_car_parking_spaces    0
# adr                            0
# customer_type                  0
# days_in_waiting_list           0
# deposit_type                   0
# booking_changes                0
# dtype: int64

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# > Hotel Bookings Analysis has 32 different variables (Continuous & Categorical) in the columns and grouping them into 7 gropus as follows:
#
# *   Guest Demographics : country, adults, children, babies.
# *   Arrival Information : arrival_date_year, arrival_date_month, arrival_date_week_number, arrival_date_day_of_month.
# *   Reservation Status : reservation_status, reservation_status_date, is_canceled, lead_time, days_in_waiting_list.
# *   User Actions : is_repeated_guest, previous_cancellations, previous_bookings_not_canceled.
# *   Accommodation Details : stays_in_weekend_nights, stays_in_week_nights, reserved_room_type, assigned_room_type, meals, required_car_parking_spaces, total_of_special_requests.
# *   Booking Information : 	hotel, market_segment, distribution_channel, booking_changes, deposit_type, agent, company, customer_type.
# *   Average Daily Rate : adr.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# std         0.483168     106.903309           0.707459
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# std                   13.589971                   8.780324
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
# Here we can see that adr has max value of 5400, which doesnt make sense.
# adr is also crucial for our analysis.
df["adr"].plot(kind = "box")
# Out:
# <Axes: >

# %%
# Here from plot we can see that one outlier is 5400. so we need to remove it.
df = df[df["adr"]<5000]

# %%
# We will again check the adr max value.
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118897.000000  118897.000000      118897.000000
# mean        0.371347     104.312018        2016.157657
# std         0.483167     106.903570           0.707462
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118897.000000              118897.000000
# mean                  27.166674                  15.800802
# std                   13.589966                   8.780321
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# **Now adr has max value of 510.**

# %% [markdown]
# ### Variables Description

# %% [markdown]
# > Describing each variable in detail :
#
# *   **hotel :** This variable describes the category of the hotels, they are City Hotel & Resort Hotel.
# *   **is_canceled :** The column shows cancellation details, 0 indicates booking not cancelled & 1 indicates booking is cancelled.
# *   **lead_time :** This column defines the time between reservation & actual arrival.
# *   **arrival_date_year :** This variable shows the arrival year of the customer namely 2015, 2016 or 2017.
# *   **arrival_date_month :** This variable shows the arrival month of the customer in between January to December.
# *   **arrival_date_week_number :** This column shows the arrival week of the customer.
# *  **arrival_date_day_of_month :** This variable indicates the arrival date of the customer in the respective month & year.
# *   **stays_in_weekend_nights :**	This variable indicates the number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the respective hotel.
# *   **stays_in_week_nights :** This column shows number of week nights (Monday to Friday) the guest stayed or booked to stay at the respective hotel.
# *   **adults :** This variable shows the number of adults present with the customer.
# *   **children :** This column shows the number of children present with the customer.
# *   **babies :** This variable shows the number of babies present with the customer.
# *   **meal :** This column shows the type of meal booked by the customer. Namely - **1.** **BB** - Bread & Breakfast, only breakfast is booked, **2. FB** - Full Board, in which breakfast, lunch & dinner are included, **3. HB** - Half Board, in which breakfast & dinner are included, **4. SC** - Self Catering, no meals are included.
# *   **country :** This column shows the origin country of customers.
# *   **market_segment :** 	This column shows the designation of the customers, namely - Aviation, Direct, Corporate, Complementary, Groups, Offline TA/TO, Online TO.
# *   **distribution_channel :** 	Booking distribution channel like direct, corporate, TA/TO, GDS.
# *   **is_repeated_guest :** This variable shows the value indicating if the booking name was from a repeated guest. **0** - **is not repeated guest** & **1**-**repeated guest.**
# *   **previous_cancellations :** 	This column shows the number of previous bookings that were cancelled by the customer prior to the current booking.
# *   **previous_bookings_not_canceled :** This variable shows the number of previous bookings not cancelled by the customer prior to the current booking.
# *   **reserved_room_type :** This variable indicates the room reserved by the customer.
# *   **assigned_room_type :** This variable shows the assigned room to the customer.
# *   **booking_changes :** This column shows the number of changes made to the booking.
# *   **deposit_type :** This variable indicates if the customer made a deposit to guarantee the booking. 3 categories: **No Deposit** – no deposit was made; **Non Refund** – a deposit was made in the value of the total stay cost; **Refundable** – a deposit was made with a value under the total cost of stay.
# *   **agent :** This column shows the id of the booking agent.
# *   **company :** This variable indicates the id of the company making a booking.
# *   **days_in_waiting_list :** This column depicts the number of days the booking was in the waiting list before it was confirmed to the customer.
# *   **customer_type :** This variable shows 4 types of customers, namely - **Contract** - when the booking has an allotment or other type of contract associated to it; **Group** – when the booking is associated to a group; **Transient** – when the booking is not part of a group or contract, and is not associated to other transient booking; **Transient-party** – when the booking is transient, but is associated to at least other transient booking
# *   **adr :** This variable shows the **Average Daily Rate** as defined by dividing the sum of all lodging transactions by the total number of staying nights.
# *   **required_car_parking_spaces :** This column indicates the number of car parking spaces required by the customer.
# *   **total_of_special_requests :** This variable shows the number of special requests made by the customer (e.g. twin bed, high floor).
# *   **reservation_status :** This column shows the reservation status of the customer whether the customer has checked-in or cancelled or not shown.
# *   **reservation_status_date :** This variable indicates date of making reservation status.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()
# Out:
# hotel                                2
# is_canceled                          2
# lead_time                          479
# arrival_date_year                    3
# arrival_date_month                  12
# arrival_date_week_number            53
# arrival_date_day_of_month           31
# stays_in_weekend_nights             15
# stays_in_week_nights                33
# adults                              14
# children                             5
# babies                               5
# meal                                 5
# country                            177
# market_segment                       7
# distribution_channel                 5
# is_repeated_guest                    2
# previous_cancellations              15
# previous_bookings_not_canceled      73
# reserved_room_type                  10
# assigned_room_type                  12
# booking_changes                     21
# deposit_type                         3
# days_in_waiting_list               128
# ...

# %% [markdown]
# Here in the above we can see that
#
# **What is the unique values of each variables above**.

# %% [markdown]
# ## 3. ***Data Wrangling*** **And Visualizations**

# %%
# Write your code to make your dataset analysis ready.
# To know the most preferred type of meal by customers
plt.figure( figsize = (6, 7))
sns.countplot(x = df['meal'])
plt.show()

# %% [markdown]
# > **Findings:**
#
# BB = is the most preffered meal.

# %%
# Adding 'stays_in_weekend_nights' & 'stays_in_week_nights' to get total stay duration
df['total_stay'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']

# %%
# To find the most preferred length of stay in each hotel
not_canceled = df[df['is_canceled'] == 0]
s1 = not_canceled[not_canceled['total_stay'] < 15]
plt.figure(figsize = (9,7))
sns.countplot(x = s1['total_stay'], hue = s1['hotel'])
plt.show()

# %% [markdown]
# > **Findings:**
# - From the above bar graph, we can see that most preferred stay is 3 days. Most of the customers prefer City Hotel for shorter stay and Resort Hotel for longer stays.
#
# > **Solution:**
# - As customers are preferring Resort Hotel for longer stay, hotel management can introduce free gift coupons, loyalty service, complimentary services and combo tourism packages for nearby places in order to make customers redundent, which will increase revenue as well.

# %%
# To identify which room type is in most demand and which room type generate the highest adr.
fig, axes = plt.subplots(1, 2, figsize = (20, 9))
room = df.groupby('assigned_room_type')
df['Num_of_bookings'] = room.size()
sns.countplot(ax = axes[0], x = df['assigned_room_type'])
sns.boxplot(ax = axes[1], x = df['assigned_room_type'], y = df['adr'])
plt.show()

# %% [markdown]
# > **Findings:**
# - From the above graphs, we can identify that roomtype A is the most demanded rooms by the customer while booking, whereas room types H,G,C are generating more ADR respectively.
#
# > **Advice On Observations:**
# - Hotel management sholud consider to increase room types A, H in order to get more revenue and increase adr respectively.

# %%
# To find which country customers have highest bookings.
country_visitors = df['country'].value_counts()[:10]
country_visitors
# Out:
# PRT    48585
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
# ITA     3766
# IRL     3375
# BEL     2342
# BRA     2224
# NLD     2104
# Name: country, dtype: int64

# %% [markdown]
# > **Findings:**
# Portugal have highest customers bookings.

# %%
# First we will count the Reservation Status Count. How many is cancelled and how many are not?
cancelled_percentage = df["is_canceled"].value_counts(normalize = True)
cancelled_percentage
# Out:
# 0    0.628653
# 1    0.371347
# Name: is_canceled, dtype: float64

# %%
# Visualization of Reservation Status Count.
plt.figure(figsize = (5,4))
plt.title("Reservation Status Count")
plt.bar(['Not cancelled','Cancelled'],df['is_canceled'].value_counts(),edgecolor = 'y',width = 0.5)
plt.show()

# %%
# Here we are checking Reservation Status Hotel Wise.
plt.figure(figsize = (7,5))
ax1 = sns.countplot(x = "hotel" ,hue = "is_canceled",data = df)
legend_labels = ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor = (1,1))
plt.title("Reservation Status Hotel Wise" ,size = 18)
plt.xlabel("hotel")
plt.ylabel("Number of Reservations")
# Out:
# Text(0, 0.5, 'Number of Reservations')

# %% [markdown]
# **Note:**
#
# **0 =** Booking Not Cancelled.
#
# **1 =** Booking Cancelled

# %% [markdown]
# > **Findings:**
#
# - City Hotel has more bookings and cancellations than Resort Hotel.
#
# **Reason**
#
# - **City Hotel** is **Less Expensive**.
# - Resort Hotel is more Expensive.
#
# > **Solution:**
# What City Hotel Should do to decrease cancellation ratio?
#
# **Answer:**
#
# 1. They should provide better facilities & clean environment. So they can feel relaxed.
#
# 2. Guide them using a List of info about Pouplar Places that they can visit and enjoy more.

# %%
# Here we are looking for counts of how many cancellation and not cancellation happend in resort hotel.
from unicodedata import normalize
resort_hotel = df[df["hotel"]== "Resort Hotel"]
resort_hotel["is_canceled"].value_counts(normalize = True)
# Out:
# 0    0.72025
# 1    0.27975
# Name: is_canceled, dtype: float64

# %%
# Here we are looking for counts of how many cancellation and not cancellation happend in city hotel.
city_hotel = df[df["hotel"]== "City Hotel"]
city_hotel["is_canceled"].value_counts(normalize = True)
# Out:
# 0    0.582918
# 1    0.417082
# Name: is_canceled, dtype: float64

# %%
# Now we are finding about Average Daily Rate of City & Resort Hotel.
resort_hotel = resort_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel = city_hotel.groupby('reservation_status_date')[['adr']].mean()

# %%
# Visualization of "Average Daliy Rate in City & Resort Hotel(ADR)".
plt.figure(figsize = (20,8))
plt.title('Average Daily Rate in City and Resort Hotel (ADR)',fontsize = 30)
plt.plot(resort_hotel.index,resort_hotel['adr'],label = 'Resort Hotel')
plt.plot(city_hotel.index,city_hotel['adr'],label = 'City Hotel')
plt.legend(fontsize = 20)
plt.show()

# %% [markdown]
# > **Findings:**
#
# 1. City Hotel is in **mid (ADR)**.
# There are some spikes, it may be due to weekends/holidays.
# 2. ALso, **City Hotel Price < Resort Hotel Price**.
#
# Hence, Hypothesis proved.

# %%
# We are finding about Reservation Status Date on Monthly Basis.
df["month"] = df["reservation_status_date"].dt.month
plt.figure(figsize = (15,8))
ax1 = sns.countplot(x="month",hue = "is_canceled",data = df)
plt.ylabel("Number of Reservations")
plt.legend(["not cancelled","cancelled"])
plt.show()

# %% [markdown]
# **Note:**
#
# Month is based on numbers.
#
# for example, 1 = january, 2 = february and so on.

# %% [markdown]
# > **Findings:**
#
# **Cancellation Data**
# 1. January = More cancellations
# 2. August = Lowest cancellations
#
# **Reservations Data**
# 1. August = Most reservations
# 2. December = Least reservations
#
# **Obeservation Result**
#
# - August has lowest cancellations and most reservations. Reason would be that prices were low in august due to some special occasions that happens in August.
#
# - In January and December prices were high so customer preffered cancellations and least reservations respectively.

# %%
# Here i am exploring about ADR on monthly basis.
plt.figure(figsize=(15, 8))
plt.title('ADR per month', fontsize=30)

df_filtered = df[df['is_canceled'] == 1].groupby('month')[['adr']].sum().reset_index()
sns.barplot(x='month', y='adr', data=df_filtered)

plt.show()

# %% [markdown]
# > **Findings:**
#
# 1. ADR in august month is lowest.
# 2. ADR in january month is highest.
#
# > **Observation:**
# It **proves** my **hypothesis** that "when prices are higher the cancellations will increase".

# %%
# Here i am exploring about Reservations Cancelled on the basis of top 10 countries.
cancelled_data = df[df["is_canceled"]==1]
top_10_country = cancelled_data["country"].value_counts()[:10]

# %%
top_10_country
# Out:
# PRT    27514
# GBR     2453
# ESP     2177
# FRA     1934
# ITA     1333
# DEU     1218
# IRL      832
# BRA      830
# USA      501
# BEL      474
# Name: country, dtype: int64

# %%
# Visualization about "Top 10 Countries With Reservations Cancelled".
plt.figure(figsize = (8,8))
plt.title('Top 10 countries with reservations cancelled')
plt.pie(top_10_country,autopct = '%.2f',labels = top_10_country.index)
plt.show()

# %% [markdown]
# > **Findings:**
#
# 1. Portugal has 70.07% of cancellations. Followed by GBR, ESP and so on.
#
# > **Solutions:**
#
# 1. Portugal should increase the better facilities than before by getting review about what they like and what they don't like.
# 2. They should decrease the price by giving discounts at special occasions when customers comes in big group.
# 3. They should hold promotional campaigns of what they are offering, what is the discount the will provide on special occasions, what extra facilities that they will provide that was not there beofre.

# %% [markdown]
# **Now we will find about most of the customers are coming through offline agents. Is it true or not?**

# %%
df["market_segment"].value_counts()
# Out:
# Online TA        56402
# Offline TA/TO    24159
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: market_segment, dtype: int64

# %%
df["market_segment"].value_counts(normalize = 'True')
# Out:
# Online TA        0.474377
# Offline TA/TO    0.203193
# Groups           0.166581
# Direct           0.104696
# Corporate        0.042987
# Complementary    0.006173
# Aviation         0.001993
# Name: market_segment, dtype: float64

# %% [markdown]
# > **Findings:**
# - According to analysis, we found out that almost half of the customers are coming through online agents.
#
# Thus, **Hypothesis is wrong.**

# %%
# We will find out about counts of cancellations in different market segment.
cancelled_data["market_segment"].value_counts(normalize = 'True')
# Out:
# Online TA        0.469696
# Groups           0.273985
# Offline TA/TO    0.187466
# Direct           0.043486
# Corporate        0.022151
# Complementary    0.002038
# Aviation         0.001178
# Name: market_segment, dtype: float64

# %% [markdown]
# > **Findings:**
# 1. Almost 47% customers coming through online agents cancel their bookings.
#
# **Reason:**
#
# This may be due to online pictures of hotel was awesome. But when customers visited, it was not as they saw.
#
# **Solutions:**
#
# - Hotel should portray what is real in the hotel, so customers won't be dissaponted when they visit hotel.
# - All the Facilities that they show and Discounts on food and services they provide should meet the customer expectatons.

# %% [markdown]
# **Now We check the prices of cancelled bookings, are they high ?**

# %%
cancelled_df_adr = cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_df_adr.reset_index(inplace=True)
cancelled_df_adr.sort_values('reservation_status_date', inplace=True)

not_cancelled_data = df[df['is_canceled']==0]
not_cancelled_df_adr = not_cancelled_data.groupby('reservation_status_date')[['adr']].mean()
not_cancelled_df_adr.reset_index(inplace=True)
not_cancelled_df_adr.sort_values('reservation_status_date', inplace=True)

plt.figure(figsize =(20,6))
plt.title('Average Daily Rate')
plt.plot(not_cancelled_df_adr['reservation_status_date'], not_cancelled_df_adr['adr'], label= 'not cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'], cancelled_df_adr['adr'], label= 'cancelled')
plt.legend()

# %% [markdown]
# > **Findings:**
# - As we can see from the start till between 2015 "not cancelled" data is not present.
# - So we will take date from when it is present.

# %%
cancelled_df_adr = cancelled_df_adr[(cancelled_df_adr['reservation_status_date'] > '2016') & (cancelled_df_adr['reservation_status_date'] < '2017-09')]
not_cancelled_df_adr = not_cancelled_df_adr[(not_cancelled_df_adr['reservation_status_date'] > '2016') & (not_cancelled_df_adr['reservation_status_date'] < '2017-09')]

# %%
plt.figure(figsize =(20,6))
plt.title('Average Daily Rate')
plt.plot(not_cancelled_df_adr['reservation_status_date'], not_cancelled_df_adr['adr'], label= 'not cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'], cancelled_df_adr['adr'], label= 'cancelled')
plt.legend()
plt.show()

# %% [markdown]
# > **Findings:**
#
# - Cancelled line is more than not cancelled line.
#
# > **Proves:**
#
# - It proves that the price have the effect on the cancellations.
#
#
# > **So after analysing and Visualizing all the above:**
# - we can say that **ADR is the most influencing factor on the cancellations rate.**

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# 1. Cancellation rates rise as the price does. In order to prevent cancellations of reservations,
# hotels could work on their pricing strategies and try to lower the rates for specific hotels
# based on locations. They can also provide some discounts to the consumers.
# 2. As the ratio of the cancellation and not cancellation of the resort hotel is higher in the
# resort hotel than the city hotels. So the hotels should provide a reasonable discount on the
# room prices on weekends or on holidays.
# 3. In the month of January, hotels can start campaigns or marketing with a reasonable
# amount to increase their revenue as the cancellation is the highest in this month.
# 4. They can also increase the quality of their hotels and their services mainly in Portugal to
# reduce the cancellation rate.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# - As the City Hotel has more bookings, it generates more revenue and it has more cancellations as well.
# - Most number of bookings are made in the month of August.
# - People from Portugal has made most number of hotel bookings and also cancellations.
# - ADR is the most influencing factor on the cancellations rate.
# - Most of the customers books through online agents rather than offline agents.
# - 47% customers coming through online agents cancel their bookings.
# - Cancellations rate increases when price is higher.
# - January has highest cancellations rate on the basis of month.
# - BB is the most preffered meal.
# - The most preferred length of stay is 3 days.
# - Most of the customers prefer City Hotel for shorter stay and Resort Hotel for longer stays.
# -  Roomtype A is the most demanded rooms by the customer while booking, whereas room types H,G,C are generating more ADR respectively.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
